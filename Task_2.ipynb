# %% [markdown]
# <a href="https://colab.research.google.com/github/GitHub-Aditya14Raj/PRODIGY_GAI_2/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install min-dalle -q

# %%
from min_dalle import MinDalle
model = MinDalle(is_mega=True,
is_reusable=True)
# Out:
# using device cuda
# intializing TextTokenizer
# initializing DalleBartEncoder
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time
text =input("enter the prompt:  ")
seed = 6
grid_size = 2
display(model.generate_image(text, seed, grid_size))
# Out:
# enter the prompt:  cricket stadium in which cricketers are playing
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 31.3 s, sys: 335 ms, total: 31.6 s
# Wall time: 1min 7s
